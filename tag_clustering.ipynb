# %%
import pandas as pd
from sklearn.cluster import KMeans, DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer
import collections
from pprint import pprint
from nltk.corpus import stopwords

# %% [markdown]
# # Análise das tags
#
# Utilizando a relação da frequência de cada uma das palavras, pude utilizar como entrada como a distancia entre cada uma das tags para um algoritmo de clusterização. o algoritmo utilizado foi o DBSCAN, principalmente por não precisar setar o numero de clusters. agora, temos uma repação de tags relacionadas, que serão utlizadas em meu modelo de recomendação.

# %% [markdown]
# ## Primeiras análises dos clusters
#
# Analisando superficialmente os grupos obtidos, podemos ver diversas razões para agrupamento: como nome do ator, tipo do filme, trilha sonora... com essa análise naao é possível demonstrar se a tag está recomendando ou apontando falhas do filme.
#
# Alguns dos grupos de tags que nao esperava achar:
#
# - [Bechdel Test:Pass](https://en.wikipedia.org/wiki/Bechdel_test)
# - Better than the first
# - true to the book
#
#
# ## Proximos passos
#
# o rating vai ser um crivo final nessa etapa: explorarei filtrar tags com média muito baixa, ou, o que considero ideal, vincular de alguma forma a nota do usuario a sua tag.
#
# Essa será a estratégia para a fase final do projeto.

# %%
def cluster_tags(texts):
    text_frequencies = TfidfVectorizer(lowercase=True,
                                 stop_words='english', 
                                 ngram_range=(1, 3),
                                 strip_accents='unicode').fit_transform(texts)
    
    clustering_model = DBSCAN().fit(text_frequencies)
    clustering = collections.defaultdict(list)
 
    for idx, label in enumerate(clustering_model.labels_):
        clustering[label].append(texts[idx])
 
    return clustering

# %%
tags = pd.read_csv("teste_elo7/ml-20m/tags.csv")
print(tags.shape)
tags = tags[tags.tag.isna() == False]

simple_tags = tags[tags['tag'].str.split().apply(len) <= 5].tag.unique()
# Out:
# (465564, 4)

# %%
clusters = cluster_tags(y)
pprint(dict(simple_tags))
# Out:
# {-1: ['Mark Waters',
#       'dark hero',
#       'noir thriller',
#       'bollywood',
#       'screwball comedy',
#       'mars',
#       'neo-noir',
#       'jesus',
#       'dragon',
#       'conspiracy theory',
#       'treasure',
#       'stranded',
#       'Oscar (Best Foreign Language Film)',
#       'New Zealand',
#       'surreal',
#       'unusual',
#       'emotional',
#       'girls who play boys',
#       'Stephen Chow',
#       'animation',
#       'beautiful',
#       'feminist',
#       'Ice',
#       'music',
#       'musical',
#       'pacing',
#       'royalty',
#       'siblings',
#       'storyline',
#       'themes',
#       'unnecessary villain',
#       'voice acting',
#       'writing',
#       'dark comedy',
#       'drugs',
#       'Nudity (Full Frontal - Notable)',
#       'Nudity (Full Frontal)',
#       'Christopher Guest',
#       'music business',
#       'rock and roll',
#       'satire',
#       'witty',
#       'Nudity (Topless - Notable)',
#       'Nudity (Topless)',
#       'sexuality',
#       'teen comedy',
#       'College Humor',
#       'Ryan Reynolds',
#       'Teen movie',
#       'college',
#       'Seann William Scott',
#       'Vince Vaughn',
#       'Will Ferrell',
#       'Funniest Movies',
#       'Steve Carell',
#       'crude humor',
#       'Seth Rogen',
#       'sex',
#       'sex comedy',
#       'arms dealer',
#       'Nicolas Cage',
#       'Tarantino',
#       'Nudity (Topless - Brief)',
#       'Highly quotable',
#       'pornography',
#       'virginity',
#       'Adam Sandler',
#       'exaggerated',
#       'Israeli/Palestinian conflict',
#       'will ferrell',
#       '1960s',
#       'Bill Nighy',
#       'meandering',
#       'Philip Seymour Hoffman',
#       'pirate radio',
#       'soundtrack',
#       'mental illness',
#       'Zach Galifianakis',
#       'golf',
#       'sports',
#       'Arnold Schwarzenegger',
#       'christmas movie',
#       'Xmas theme(?)',
#       'American football',
#       'football',
#       'sport:American football',
#       'high school',
#       'great ending',
#       'lyrical',
#       'melancholy',
#       'psychology',
#       'reflective',
#       'suburbia',
#       'suicide',
#       'visually appealing',
#       'David Spade',
#       "fuck you it's funny",
#       'alternate timeline',
#       'cult film',
#       'thought-provoking',
#       'Al Sharpton',
#       'Winona Ryder',
#       'Ben Stiller',
#       'Funny as hell',
#       'Idiotic',
#       'wasted potential',
#       'Judd Apatow movie',
#       'Paul Rudd',
#       'Steve Carrell',
#       'avante garde',
#       'bittersweet',
#       'deadpan',
#       'FATHERS AND SONS',
#       'independent film',
#       'Indie',
#       'irreverent',
#       'SEXUAL AWAKENING',
#       'unique',
#       'friendship',
#       'tattoo',
#       'teenager',
#       'delusion',
#       'delusional',
#       'dork people',
#       'family affair',
#       'real doll',
#       'small town',
#       'brother-brother relationship',
#       'let down',
#       'Jack Black',
#       'Robert Downey Jr.',
#       'Tom Cruise',
#       'Vietnam War',
#       'handcam-real style',
#       'parody',
#       'vampires',
#       'Emma Stone',
#       'funny dialogues',
#       'typical',
#       'Unreal reactions',
#       'plot twist',
#       'documentary',
#       'makes you think',
#       'social networking',
#       'drug use',
#       'road trip',
#       'camping trip',
#       'emma watson',
#       'beautifully filmed',
#       'quirky',
#       'romance',
#       'stylized',
#       'whimsical',
#       'culture clash',
#       'heartbreaking',
#       'sad but good',
#       'Steven Spielberg',
#       'manhattan',
#       'upper class',
#       'whit stillman meets Diner',
#       'actress too old',
#       'too upper class',
#       'wild and fresh',
#       'whit stillman meets diner',
#       'utterly predictable ensemble flick',
#       'Simon Pegg',
#       'Audrey Hepburn',
#       'Gregory Peck',
#       'imdb top 250',
#       'Italy',
#       'National Film Registry',
#       'romantic comedy',
#       'Rome',
#       'slapstick',
#       'zest for life',
#       'British',
#       'Hugh Grant',
#       'Jane Austen',
#       'sentimental',
#       'Freddie Highmore',
#       'inspirational',
#       'love of music',
#       'power of music',
#       'uplifting and compelling',
#       'Firefly',
#       'scifi',
#       'western',
#       '1970s',
#       'fantasy',
#       'Revenge',
#       'Willem Dafoe',
#       'twist',
#       'overrated',
#       'post-apocalyptic',
#       'organized crime',
#       'twist ending',
#       'twists & turns',
#       'masterplan',
#       'Morgan Freeman',
#       'prison escape',
#       'redemption',
#       'revenge',
#       'vietnam war',
#       'crime gone awry',
#       'black comedy',
#       'cold war',
#       'Peter Sellers',
#       'satirical',
#       'Stanley Kubrick',
#       'John Cleese',
#       'Monty Python',
#       'atmospheric',
#       'psychological',
#       'Clint Eastwood',
#       'Ennio Morricone',
#       'Italian',
#       'Sergio Leone',
#       'Michael Douglas',
#       'Sean Penn',
#       'eugenics',
#       'future',
#       'genetic engineering',
#       'genetics',
#       'powerful ending',
#       'racism',
#       'Jack Nicholson',
#       'obsessive compulsive disorder',
#       'relationships',
#       'Edward Norton',
#       'Neo-Nazis',
#       'politics',
#       'tense',
#       'virtual reality',
#       'adventure',
#       'anime',
#       'fantasy world',
#       'cycling',
#       'pretentious',
#       'slow paced',
#       'epic',
#       'fighting',
#       'photography',
#       'lawyers',
#       'military court',
#       'multiple storylines',
#       'nonlinear',
#       'disturbing',
#       'drama',
#       'action packed',
#       'dystopia',
#       'unrealistic characters',
#       'Johnny Depp',
#       'magic realism',
#       'modernism',
#       'colours',
#       'dialogue driven',
#       'mindfuck',
#       'plot holes',
#       'Biography',
#       'excellent performance',
#       'historical',
#       'World War II',
#       'comic book',
#       'England',
#       'Natalie Portman',
#       'Miami',
#       'shallow',
#       'unrealistic action',
#       'unrealistic plot',
#       'death',
#       'Music',
#       'americanized movie',
#       'based on a comic',
#       'based on comic',
#       'Frank Miller',
#       'despair',
#       'ending twist',
#       'great soundtrack',
#       'madness',
#       'spaceships',
#       'French',
#       'murder mystery',
#       'Middle East',
#       'revolution',
#       'social commentary',
#       'entirely dialogue',
#       'Excellent use of dialogue',
#       'immortality',
#       'intellectual',
#       'Underrated',
#       'Atmospheric',
#       'Batman',
#       'Heath Ledger',
#       'superhero',
#       'vigilante',
#       'India',
#       'Oscar (Best Picture)',
#       'shallow plot',
#       'gangs',
#       'alien invasion',
#       'aliens',
#       'boring plot',
#       'nonsensical',
#       'stupid characters',
#       'beautiful scenery',
#       'Bible',
#       'Christianity',
#       'Denzel Washington',
#       'dystopic future',
#       'fight scenes',
#       'cheating',
#       'cold',
#       'husband-wife relationship',
#       'lack of identification',
#       'unlikable characters',
#       'long revenge',
#       'spanish',
#       'unpredictable',
#       'coma',
#       'family bonds',
#       'George Clooney',
#       'Hawaii',
#       'adapted from:book',
#       'philosophy',
#       'rebellion',
#       'social criticism',
#       'Tom Hanks',
#       'Leonardo DiCaprio',
#       'Quentin Tarantino',
#       'slavery',
#       'marriage',
#       'meticulous',
#       'Neal Patrick Harris',
#       'netflix',
#       'oppl',
#       'Good Book Bad Movie',
#       'Ireland',
#       'Irish',
#       'NOT British',
#       'KATHARINE Hepburn',
#       'anti-abortion',
#       '\xa0oppl',
#       'new',
#       'france',
#       'feminism',
#       'Kevin Pederast',
#       "'Oh The Whore-ror!'",
#       "You Mean It's Over Inflated!",
#       'Guy Pierce With Dweeb Focals',
#       'the book was bettah',
#       'Great Anti-Abortion Film',
#       'Re-Fried For U.S.',
#       "'Don't Watch 'Criminal' Totally Butchered'",
#       '\'H Christ!"',
#       "...'Livin' In An Amish Paradise'",
#       'Loved The Mouse Wake-Up',
#       'Just Another F***ing A-Hole!',
#       'Merde!',
#       'Teen Induced Angst Overdose',
#       'Half-Assed Productions',
#       "'Priceline Negotiator!'",
#       'The Power Of The P',
#       'A Comedy Version Of Matchpoint',
#       "'Double Fudge Bus'",
#       'Rwanda Genocide',
#       'Rwandan Genocide',
#       "'There's Shit In The Meat!'",
#       'It Just Keeps Getting Better',
#       'Rear Pwnage',
#       "'Saving Silverman Part Deux'",
#       'Chuck & Buck...',
#       "'More Like Skankwalkers'",
#       'Super De-Formed',
#       "'STFU!'",
#       "'I Love You Anna!'",
#       '30 Daze Of Shite',
#       "'Heads Or Tails...Call It'",
#       'I felt sweded',
#       "'Cate Dylan Hmmm...'",
#       'blair gojira project',
#       'brain bang',
#       'not another herzog schwarzenneger egomentary',
#       "...that it's finally over",
#       "'stop wanking",
#       "or you'll go...too late'",
#       "mickey 'the stretch' rourke",
#       'shame on them!',
#       'angles and deadlines',
#       'crash re-hashed',
#       'good first try for MCG',
#       'better method AI',
#       'needed more autobots',
#       '"Tonite',
#       'Act From',
#       'Hell!"',
#       'angels',
#       'true love',
#       'Katie Holmes',
#       'Timothy Olyphant',
#       'Honor',
#       'narrated',
#       'change',
#       'Change of heart',
#       'breaking the fourth wall',
#       'roadtrip',
#       'great acting',
#       'mexican stand off',
#       'tension',
#       'disappointing',
#       'Milla Jovovich',
#       'bad cameo',
#       'waste of time',
#       'Michelle Williams',
#       'bad acting',
#       'childish',
#       'Rosario Dawson',
#       'Ewan McGregor',
#       'great house',
#       'location',
#       'Pierce Brosnan',
#       'clever plot',
#       'poor plot',
#       'dreams',
#       'open ending',
#       'Michael Cera',
#       'dull',
#       'motorcycle',
#       'weak dialoges',
#       'Emily Blunt',
#       'Russell Brand',
#       'dissapointing',
#       'Sam Rockwell',
#       'Elizabeth Banks',
#       'naive',
#       'socjopat',
#       'clever',
#       'Julia Dietze',
#       'pointless',
#       'Mark Wahlberg',
#       'Christopher Walken',
#       'Woody Harrelson',
#       'gets worse as it goes',
#       'cleavage',
#       'Jai Courtney',
#       'Skylar Astin',
#       'advertising',
#       'corporations',
#       'rushed ending',
#       'makes no sense',
#       'David Bowie',
#       'holdem',
#       'Jeff Bridges',
#       'Marvel',
#       'military',
#       'murder',
#       'torture',
#       'Bunuel',
#       'Dali',
#       'experimental',
#       'surrealism',
#       'mumblecore',
#       'ddd',
#       'strong women',
#       'marvelous',
#       'iconic',
#       'Brad Pitt',
#       'corruption',
#       'docudrama',
#       'Russell Crowe',
#       'true story',
#       'ethics',
#       'nonsense',
#       'Beautiful story.',
#       'wacky',
#       'corny humor',
#       'nice visuals',
#       'shaky camera',
#       'father-son relationship',
#       'prison',
#       'Robin Williams',
#       'Steve Martin',
#       'Martin Scorsese',
#       'Robert De Niro',
#       '1980s',
#       'sexual',
#       'alternate reality',
#       'Tim Burton',
#       'High School',
#       'teen',
#       'South America',
#       'survival',
#       'conspiracy',
#       'Studio Ghibli',
#       'zombies',
#       'midlife crisis',
#       'marijuana',
#       'High school life',
#       'Stoner Movie',
#       'clint eastwood',
#       'gangsters',
#       'Animation',
#       'Las Vegas',
#       'loneliness',
#       'cyberpunk',
#       'Keanu Reeves',
#       'Jim Parsons',
#       'complex',
#       'MILITARY LIFE',
#       'mythology',
#       'religion',
#       'space',
#       'Jet Li',
#       'Sexualized violence',
#       'Foreign',
#       'Handycam',
#       'documentary style',
#       'IMDB Top 250',
#       'role reversal',
#       'war',
#       'Beauty',
#       'chaos',
#       'cinematography',
#       'technobabble',
#       'video games',
#       'Jake Gyllenhaal',
#       'adapted from:comic',
#       'campy',
#       'dieselpunk',
#       'Hero',
#       'Bruce Willis',
#       'short-term memory loss',
#       'courtroom drama',
#       'arnold',
#       'spielberg',
#       'cheerleading',
#       'christian',
#       'satire:art world',
#       'mountain climbing',
#       'Christian Bale',
#       'John Cusack',
#       'Special Effects',
#       'car chase',
#       'heist',
#       'Action/Comedy',
#       'Crime',
#       'Drugs',
#       'Guy Ritchie',
#       'Greg Kinnear',
#       'president',
#       'Alicia Silverstone',
#       'teacher',
#       'tearful',
#       'Kevin Costner',
#       'Meg Ryan',
#       'Beethoven',
#       'Gary Oldman',
#       'albert einstein',
#       'Einstein',
#       'Tim Robbins',
#       'freedom',
#       'morgan freeman',
#       'stephen king',
#       'tim robbins',
#       'Star Trek',
#       'Sandra Bullock',
#       'Emma Thompson',
#       'Shakespeare',
#       'nanny',
#       'Denis Leary',
#       'Kevin Spacey',
#       'hitler',
#       'chess',
#       'ownable',
#       'Julia Roberts',
#       'prince charming',
#       'prostitution',
#       'Richard Gere',
#       'aids',
#       'assisted suicide',
#       'friends',
#       'hiv',
#       'homosexuality',
#       'Uma Thurman',
#       'Helen Hunt',
#       'Bill Pullman',
#       'Forest Whitaker',
#       'genius',
#       'John Travolta',
#       'Kyra Sedgwick',
#       'telekinesis',
#       'yellow brick road',
#       'Julie Andrews',
#       'chocolate',
#       'Gene Wilder',
#       'morals',
#       'Patrick Swayze',
#       'humorous',
#       'Civil War',
#       'Andie MacDowell',
#       'Bill Murray',
#       'Chris Elliott',
#       'Stephen Tobolowsky',
#       'trapped',
#       'weatherman',
#       'subtitles',
#       'billy crystal',
#       'meg ryan',
#       'Olivia Newton-John',
#       'blooper reel',
#       'lawyer',
#       'Kelly Preston',
#       'Matthew Broderick',
#       'spying',
#       'stars',
#       'TchÃ©ky Karyo',
#       'Cameron Diaz',
#       'weddings',
#       'Will Smith',
#       'pirates',
#       'treasure hunt',
#       'alabama',
#       'Joe Pesci',
#       'Marisa Tomei',
#       'trial',
#       'Don Knotts',
#       'Jeff Daniels',
#       'Reese Witherspoon',
#       'Tobey Maguire',
#       'William H. Macy',
#       'father',
#       'holocaust',
#       'son',
#       'Bill Lumberg',
#       'corporate America',
#       'race issues',
#       'lesbian',
#       'Pixar',
#       'D.B. Sweeney',
#       'figure skating',
#       'hockey',
#       'Moira Kelly',
#       'Roy Dotrice',
#       'Peter Pan',
#       'non-verbal',
#       'Angelina Jolie',
#       'cars',
#       'crime',
#       'Giovanni Ribisi',
#       'Robert Duvall',
#       'ballet',
#       'Julia Stiles',
#       'hacking',
#       'Luke Wilson',
#       'Selma Blair',
#       'Billy Crystal',
#       'Jennifer Tilly',
#       'John Goodman',
#       'Andy Garcia',
#       'Bernie Mac',
#       'casino',
#       'biography',
#       'Patrick Dempsey',
#       'mini coopers',
#       'school',
#       'Olympics',
#       'USA',
#       'Drew Barrymore',
#       'Michael Moore',
#       'puppets',
#       'powers',
#       'Star Wars',
#       'animals',
#       'penguins',
#       'winter',
#       'Owen Wilson',
#       'gender',
#       'transgender',
#       'Alfred Hitchcock',
#       'James Stewart',
#       'paranoid',
#       'Musical',
#       'Woody Allen',
#       'existentialism',
#       'fanciful',
#       'toys',
#       'Ridley Scott',
#       'sword fight',
#       'Michael Caine',
#       'Eddie Murphy',
#       'androids',
#       'artificial intelligence',
#       'robots',
#       'crappy sequel',
#       'Eva Mendes',
#       'street race',
#       'heroine in tight suit',
#       'sexy',
#       'eva green',
#       'Jacques Becker',
#       'great cinematography',
#       'Keira Knightley',
#       'coen brothers',
#       'Tommy Lee Jones',
#       'the end',
#       'Jan Svankmajer',
#       'animated',
#       'anti-hero',
#       'heartwarming',
#       'Vin Diesel',
#       'Iron Man',
#       'Spaghetti Western',
#       'oldschool',
#       'Disappointing',
#       'Black comedy',
#       'rape',
#       'Southern theme',
#       'dreamlike',
#       'David Lynch',
#       "women's lib",
#       'Alan Cumming',
#       'wes anderson',
#       'joss whedon',
#       'Humphrey Bogart',
#       'thriller',
#       'Dragon Ball',
#       'opposites attract',
#       'tv miniseries',
#       'Maggie Gyllenhaal',
#       'childhood fav',
#       'Jim Carrey',
#       'Simon Callow',
#       'Steve Oedekerk',
#       'betrayal',
#       'Mike Myers',
#       'Christopher Nolan',
#       'Charlize Theron',
#       'Love&War',
#       'PenÃ©lope Cruz',
#       'Unpredictable',
#       'meditative',
#       'Business is the antagonist',
#       'not convincing',
#       'poor acting',
#       'obvious plot',
#       'boring beginning',
#       'Kevin Bacon',
#       'Oliver Platt',
#       'Kate Winslet',
#       'Ralph Fiennes',
#       'honest',
#       'wandering',
#       'biblical references',
#       'black and white morals',
#       'thoughtful',
#       'War',
#       'Alison Lohman',
#       'hackers',
#       'internet',
#       'poorly directed',
#       'bad humor',
#       'jack nicholson',
#       'america porn',
#       'cheesy',
#       'Quirky',
#       'detective movie',
#       'directorial debut',
#       'neo noir',
#       'self-mocking',
#       'exciting',
#       'galactic',
#       'Reverse',
#       'Twist',
#       'unsafe drill use',
#       'amazing storytelling',
#       'Old',
#       'drana',
#       'realism',
#       'baseball',
#       'marx brothers',
#       'mel brooks',
#       'dr. seuss',
#       'Helen Mirren',
#       'Rachel McAdams',
#       'Harrison Ford',
#       'apocalypse',
#       'aviation',
#       'disaster',
#       'ensemble cast',
#       'Oscar Winner',
#       'Saturn Award (Best Special Effects)',
#       'US President',
#       'George Lucas',
#       'original plot',
#       'star wars',
#       'sword fighting',
#       'fairy tale',
#       'good versus evil',
#       'medieval',
#       'Mark Hammill',
#       'I just lost the game',
#       'undercover cop',
#       'high fantasy',
#       'magic',
#       'nature',
#       'Oscar (Best Cinematography)',
#       'scenic',
#       'Tolkien',
#       'wizards',
#       'Robert Redford',
#       'christianity',
#       'futuristic',
#       'pregnancy',
#       'bruce willis',
#       'computers',
#       'terrorism',
#       'United States',
#       'ambiguous ending',
#       'big budget',
#       'complicated',
#       'Ellen Page',
#       'Tokyo',
#       'antihero',
#       'comics',
#       'DC',
#       'jason todd',
#       'Joker',
#       'MY PARENTS ARE DEEEAAADDDD',
#       'no Kevin Conroy',
#       'no Mark Hamill',
#       'sympathetic villain',
#       'Jeremy Renner',
#       'Good Ending',
#       'investigation',
#       'without romance',
#       'deadpool',
#       'wolverine',
#       'fast paced',
#       'J.J. Abrams',
#       'science fiction',
#       'giant monster',
#       'giant robots',
#       'Guillermo del Toro',
#       'class conflict',
#       'psychedelic',
#       'american propaganda',
#       'Propaganda',
#       'Mindfuck',
#       'claustrophobic',
#       'depressing',
#       'psychodrama',
#       'schizophrenia',
#       'foreign language',
#       'irish accent',
#       'Coen Brothers',
#       'hitchcockian',
#       'suspense',
#       'Dark Comedy',
#       'twisted ending',
#       'Emma Roberts',
#       'beat generation',
#       'william burroughs',
#       'jazz',
#       'Tense',
#       'Sir John Candy',
#       '_jur',
#       'Yimou Zhang',
#       'Lars von Trier',
#       'Political',
#       'Ei muista',
#       'Katso Sanna!',
#       'ei muista',
#       'aboregines',
#       'Peter Gabriel music',
#       'philosophical',
#       'Kristen Bell',
#       'bromance',
#       'Jason Segel',
#       'likeable',
#       'foreign movie',
#       'police investigation',
#       'family movie',
#       'british',
#       'alcohol',
#       'alien',
#       'wierd',
#       'spy',
#       'Motivation',
#       'Feelings',
#       'romance.',
#       'Favorites',
#       'ToSee',
#       'dramatic',
#       'male nudity',
#       'memories',
#       'artistic',
#       'teenagers',
#       'tps',
#       'memory',
#       'castration',
#       'nerds',
#       'iraq',
#       'israel',
#       'palestine',
#       'Stephen King',
#       'insanity',
#       'good sequel',
#       'growing old',
#       'english',
#       'goodness of mankind',
#       'human spirit',
#       'personality over looks',
#       'shiny',
#       'high camp',
#       'Perfect',
#       'Better than expected',
#       'Shine On by needtobreathe',
#       'Istanbul',
#       'effects',
#       'cast',
#       'german sync',
#       'Bit Corny',
#       'Good Oldskool Movie',
#       'ghosts/afterlife',
#       'gothic',
#       'halloween',
#       'Philip K. Dick',
#       'gritty',
#       'mafia',
#       'Oscar (Best Supporting Actor)',
#       'visceral',
#       'amnesia',
#       'hallucinatory',
#       'identity',
#       'Post apocalyptic',
#       'steampunk',
#       'biopic',
#       'Hunter S. Thompson',
#       'Terry Gilliam',
#       'central park',
#       'chivalrous',
#       'deep',
#       'Gilliam',
#       'homeless',
#       'mental imbalance',
#       'Oscar (Best Supporting Actress)',
#       'cerebral',
#       'Al Pacino',
#       'gangster',
#       'guns',
#       'remake',
#       'enigmatic',
#       'good dialogue',
#       'Japan',
#       'Kick-Butt Women',
#       'author:william s. burroughs',
#       'David Cronenberg',
#       'Madness',
#       'gory fun',
#       'Zack Snyder',
#       'Zombie Movie',
#       'CANNIBALS',
#       'George A. Romero',
#       'Goblin',
#       'Romero',
#       'cannibalism',
#       'super-hero',
#       'Uwe Boll',
#       'author:Alan Moore',
#       'Comic Movie',
#       'teacher changing lives',
#       'Benicio Del Toro',
#       'caper',
#       'education',
#       'emotion',
#       'inspirational teacher',
#       'Richard Dreyfuss',
#       'astronauts',
#       'catastrophe',
#       'space program',
#       'SPACE TRAVEL',
#       'Dramatic',
#       'prohibition',
#       'Romance',
#       'justice',
#       'banter',
#       'Geena Davis',
#       'Michael Keaton',
#       'David Strathairn',
#       'chase',
#       'courtroom',
#       'Ed Norton',
#       'Thriller',
#       'Beverley Mitchell',
#       'espionage',
#       'Oscar (Best Directing)',
#       'John Turturro',
#       'Dustin Hoffman',
#       'Kevin Kline',
#       'archaeology',
#       'con artists',
#       'Paul Newman',
#       'poker',
#       'surprise ending',
#       'childhood',
#       'INNOCENCE LOST',
#       'Jason Bateman',
#       'Kiefer Sutherland',
#       'nostalgic',
#       'poignant',
#       'Rob Reiner',
#       'wistful',
#       'James Earl Jones',
#       'Ray Liotta',
#       'Gary Dourdan',
#       'distopia',
#       'Ethan Hawke',
#       'genetic selection',
#       'Jude Law',
#       'John Malkovich',
#       'card games',
#       'cards',
#       'court',
#       'POLITICAL CORRUPTION',
#       'Rachael Leigh Cook',
#       'Jennifer Aniston',
#       'Ron Livingston',
#       'slackers',
#       'Catherine McCormack',
#       'courtesan',
#       'empowerment',
#       'Period piece',
#       'compassionate',
#       'madonna',
#       'Golden Brooks',
#       'Michael Pitt',
#       'American Civil War',
#       'Martin Sheen',
#       'Sam Elliott',
#       'OBSESSIVE QUESTS',
#       'Casey Affleck',
#       'Don Cheadle',
#       'feel good movie',
#       'Mekhi Phifer',
#       'Ryan Gosling',
#       'sandra bullock',
#       'assassin',
#       'cia',
#       'Romany Malco',
#       'folk music',
#       'Fred Willard',
#       'journalism',
#       'Politics',
#       'autobiography',
#       'discipline',
#       'kung fu',
#       'political repression',
#       'easily confused with another title',
#       'NOT WILL SMITH',
#       'Joaquin Phoenix',
#       'secrets',
#       'feel good',
#       'soccer',
#       'censorship',
#       'political',
#       'propaganda',
#       'Robert Downey Jr',
#       'Anthony Rapp',
#       'Taye Diggs',
#       'Sanaa Lathan',
#       'world war II',
#       'Sharon Leal',
#       'Oscar (Best Sound)',
#       'spies',
#       'spy thriller',
#       'feel-good',
#       'sacrifice',
#       'atonement',
#       'Drama',
#       'foreign',
#       'NOT JONNY DEPP',
#       'Christine Lakin',
#       'Dark Humor',
#       'Depression',
#       'Schizophrenia',
#       'Daniel Radcliffe',
#       'Emma Watson',
#       'DJ Qualls',
#       'Eddie Griffin',
#       'Zooey Deschanel',
#       'Tyrese Gibson',
#       'Leslie Mann',
#       'doua moua',
#       'Surrealism',
#       'Egypt',
#       'Holocaust',
#       'childhood classics',
#       'nostalgia',
#       'Jeremy Irons',
#       'Death',
#       'Mafia',
#       'british comedy',
#       'literary adaptation',
#       'indiana jones',
#       'complex characters',
#       'afterlife',
#       'Ingmar Bergman',
#       'Sean Connery',
#       'Surreal',
#       'jim carrey',
#       'alone in the world',
#       'mathematics',
#       'terrible acting',
#       'autism',
#       'Indiana Jones',
#       'Antichrist',
#       'satanism',
#       'Anthony Hopkins',
#       'cliche ending',
#       'low budget',
#       'mimics documentary-style',
#       'mockumentary',
#       'intelligent thriller',
#       'New York',
#       'New York City',
#       'good plot',
#       'Myth',
#       'vikings',
#       'Christopher Lloyd',
#       'Robert Zemeckis',
#       'updated classics',
#       'flashbacks',
#       'hallucination',
#       'paranoia',
#       'masturbation',
#       'Dystopia',
#       'sex related humorism',
#       'split personality',
#       'superheroes',
#       'time loop',
#       'better than the american version',
#       'ghosts',
#       'anthony hopkins',
#       'jeff bridges',
#       'supernatural',
#       'Ricardo Darin',
#       'Daniel Day-Lewis',
#       'excellent script',
#       'twist-ending',
#       'sniper',
#       'controversial',
#       'fairy tales',
#       'Berlin',
#       'East Germany',
#       "Peter O'Toole",
#       'zombie',
#       'weak plot',
#       'escape',
#       'complicated plot',
#       'Twisted Ending',
#       'better than expected',
#       'mysterious or thrilling',
#       'cultural customs and traditions',
#       'indians',
#       'german',
#       'predictable ending',
#       'self discovery',
#       'futurama',
#       'Broadway',
#       'double agents',
#       'silly',
#       'dark humor',
#       'life & death',
#       'jews',
#       'stupid ending',
#       'butterfly effect',
#       'thought provoking',
#       'dance',
#       'rich and poor',
#       'technology',
#       'dumb ending',
#       'Colin Farrell',
#       'metafiction',
#       'feral children',
#       'compelling',
#       'hard science fiction',
#       'jupiter',
#       'Greenland',
#       'Iceland',
#       'Matthew McConaughey',
#       'relativity',
#       'wormhole',
#       'Ben Affleck',
#       'David Fincher',
#       'false accusation',
#       'Watched',
#       'watched',
#       'opera',
#       'excessive violence',
#       'alternate universe',
#       'possession',
#       "80's",
#       "80's classic",
#       'Brat Pack',
#       'teen angst',
#       'manipulation',
#       'Sarah Michelle Gellar',
#       'Alyson Hannigan',
#       'boxing',
#       'good plot twists',
#       'war movie',
#       'blunt existentialism',
#       'Gay Character',
#       'post apocalyptic',
#       'adultery',
#       'affair',
#       'Medieval',
#       'mel gibson',
#       'Scotland',
#       'raunchy',
#       'strippers',
#       'Sexuality',
#       'tom hanks',
#       'gay lead character',
#       'amazing photography',
#       'WWII',
#       'Area 51',
#       'will smith',
#       'imagination',
#       'horrors of war',
#       'Erotic Thriller',
#       'Notable Nudity',
#       'confrontational',
#       'group psychology',
#       'desert',
#       'antichrist',
#       'devil',
#       'brothers',
#       'enormously long battle scene',
#       'wwii',
#       'Adventure',
#       'Fantasy',
#       'vampire',
#       'Good versus evil',
#       'sword and sorcery',
#       'Michael Clarke Duncan',
#       'Steve McQueen',
#       'Nudity (Rear)',
#       'slasher',
#       'change the world',
#       'dancing',
#       'heroic',
#       'civil rights',
#       'Gene Hackman',
#       'ku klux klan',
#       'Good Romantic Comedies',
#       'Romantic Comedy',
#       'intelligent',
#       'math',
#       'factual',
#       'realistic action',
#       'classical music',
#       'nudity (full frontal)',
#       'battle of the sexes',
#       'johnny depp',
#       'skeletons',
#       'Food',
#       'immigrants',
#       'new beginning',
#       'Japanese culture',
#       'samurai',
#       'Epic',
#       'historical epic',
#       '19th century',
#       'period drama',
#       'rhythm & blues',
#       'Ancient Greece',
#       'bisexual',
#       'meryl streep',
#       'antarctica',
#       'mining',
#       'Christmas',
#       'talking animals',
#       'Meryl Streep',
#       'courage',
#       'tearjerking',
#       'determination',
#       'Football',
#       'patriotic',
#       'Biblical',
#       'Jesus',
#       '80s nostalgia',
#       'harry potter',
#       'sex scene',
#       'greed',
#       'lots of blood',
#       '1930s',
#       'Amy Adams',
#       'nudity (topless)',
#       'Viggo Mortensen',
#       'dark side of India',
#       'non-linear',
#       'Poverty',
#       'gay history',
#       'gay rights',
#       'glbt',
#       'Friendship',
#       'bad cgi',
#       'addiction',
#       'Iraq War',
#       'cooking',
#       'food',
#       'inspiring',
#       'kindness of strangers',
#       'books',
#       'authenticity',
#       'cultural authenticity',
#       'Jennifer Lawrence',
#       'ozarks',
#       'resilience',
#       'rural',
#       'white trash',
#       'dark fantasy',
#       'Harry Potter',
#       'simplified history',
#       'segregation',
#       'Tearjerker',
#       'horses',
#       'child killing',
#       'visually stunning',
#       'disability',
#       'chrisitanity',
#       'salvation',
#       'script',
#       'hostage',
#       'Iran',
#       'Political Thriller',
#       'suspenseful',
#       'Thrilling',
#       'True story',
#       "God's existance",
#       'great photograpy',
#       'religious overtones',
#       'spiritual journey',
#       'wisdom',
#       'acrobat',
#       'fugitive',
#       'unsimulated sex',
#       'believable',
#       'hijacking',
#       'ocean',
#       'Graphic Violence',
#       'gay marriage',
#       'Afghanistan',
#       'seals',
#       'apple',
#       'potato',
#       'science',
#       'tulip',
#       'Great Visuals',
#       'dystopian future',
#       'fashion',
#       'shakespeare',
#       'coming out',
#       'Joe Dante',
#       'shit on a stick',
#       'computer animation',
#       'Disney animated feature',
#       'Pixar animation',
#       'board game',
#       'childhood recaptured',
#       'herds of CGI animals',
#       'see also:Zathura',
#       'time',
#       'remadeAs:Sabrina(1995)',
#       'remakeOf:Sabrina(1954)',
#       'upstairs-downstairs',
#       'author:Mark Twain',
#       '007 (series)',
#       'killer as protagonist',
#       'author:Jane Austen',
#       'private detective',
#       'satire:Hollywood insiders',
#       "author:John O'Brien",
#       'adapted from:play',
#       'playwright:Shakespeare',
#       '18th century',
#       'setting:England',
#       'protagonist is a teacher',
#       'adapted from/inspired by:short film',
#       'nature of insanity',
#       'plot point:bio-medical danger',
#       'remake of a french film',
#       'animal:pig',
#       'barnyard animals',
#       'compare:Bright Star (2009)',
#       'compare:Carrington (1995)',
#       'protagonist is painter (artist)',
#       'protagonist is writer',
#       'Nun',
#       'twins/inter-related lives',
#       'adapted from:game',
#       'BFI modern classic',
#       'Related:Pocahontas (1995)',
#       'highschool music teacher',
#       'splatter',
#       'related:Dr. Jekyll and Mr. Hyde',
#       'setting:golf course',
#       'sport:golf',
#       'Muppets',
#       'BFI classic',
#       'killer-as-protagonist(?)',
#       'psychopath as hero',
#       'setting:NYC',
#       'Oscar:documentary',
#       'The Shoah',
#       'child abuse',
#       'setting:submarine',
#       'queer?',
#       'RemakeOf:La Cage aux folles (1978)',
#       'setting:space/Earth orbit',
#       'alter ego',
#       'Batman (series)',
#       '?adapted from:book',
#       'author:Michael Chricton?',
#       'biographical',
#       'animal:orca',
#       'animal:whale',
#       'awesome soundtrack',
#       'Bechdel Test:Fail',
#       'computer cracker',
#       'cool videogame (scene)',
#       'cyber-blackmail/intimidation',
#       'cyber-intimidation',
#       'adapted from:author',
#       'author:William Gibson',
#       'should dislike',
#       '?android(s)/cyborg(s)',
#       'psychic character',
#       'Jay and Silent Bob',
#       'librarians',
#       "protagonist is `party girl'",
#       'setting:library',
#       'protagonist is an idiot',
#       'food/cooking',
#       'remadeAs:Tortilla Soup',
#       'remakeOf:Eat Drink Man Woman',
#       'sexuality:BDSM',
#       'setting:Chicago',
#       'sport:basketball',
#       'character based on real person:Beethoven',
#       'topic:deafness',
#       'author:Anne Price',
#       'murder/fatality',
#       'author:Louisa May Alcott',
#       'male teenager(s) & female prostitute(s)',
#       'Xmas theme',
#       'courtroom setting',
#       'assassin-in-training',
#       'compare:Silas Marner (book)',
#       'killer-as-protagonist',
#       'major recutting',
#       'revenge as motive',
#       'hypertextual',
#       'MÃ´vielens bug?',
#       'not bollywood',
#       'straight plot almost unecessary',
#       'tag:needless gratuitous redundancy tag',
#       'queer',
#       'religion:Xian',
#       'setting:Church',
#       'topic:television game show',
#       'Three Colours trilogy',
#       'death of a child',
#       'disambiguation:Blue',
#       'odd-numbered ST movie',
#       'STTNG',
#       'avuncular grandfather-figure',
#       'quick change artist',
#       'gender identity',
#       'subgenre:road trip',
#       'transvestites',
#       'author:Tom Clancy',
#       'character:Jack Ryan',
#       'author:John Grisham',
#       'lawyer as protagonist',
#       'animation remade as live action',
#       'biographical view',
#       'related:Forrest Gump',
#       'related:technique:Forrest Gump',
#       'author:Rudyard Kipling',
#       'hereditary patriarchy',
#       'nature of leadership',
#       'protagonist is royal',
#       'satanically evil',
#       'animal:dog',
#       'annoying sexist stereotype mars story',
#       'disambiguation:The Mask',
#       'adapted from:TV series',
#       'gambling',
#       'news media',
#       'theme:lying',
#       'co-dependancy',
#       'werewolf',
#       'camp',
#       'author:Edith Wharton',
#       'animal:horse',
#       'drug company',
#       'FBI pursuit/case',
#       'innocent person on the run',
#       'protagonist is medical doctor',
#       'sewer/tunnel chase',
#       'the comfort food of movies',
#       'video surveillance',
#       'author:Michael Crichton',
#       'compareTo:Last Action Hero',
#       'gender disguise',
#       'nanny is secretly blood relative',
#       'author:Virginia Woolf',
#       'author:Robert Heinlein',
#       'xenophobic?',
#       'android(s)/cyborg(s)',
#       'crime-fighting/police robot',
#       'Nazis',
#       'Oscar:Editing',
#       'agent/assassin with false memories/amnesia',
#       'author:Philip K. Dick',
#       'beautiful effects',
#       'begins with big eye',
#       'cinematic watershed',
#       'living a fictional life',
#       'reference:Blade Runner',
#       'related:Blade Runner',
#       'setting:LA',
#       'group sex',
#       'Halloween theme',
#       'Xmas',
#       'potter',
#       'protagonist is recently widowed',
#       'remakeOf:Truly Madly Deeply',
#       'villain:The Joker',
#       'author:Thomas J. Harris',
#       'character:Hannibal Lecter',
#       'gruesome',
#       'prequel to:Hannibal',
#       'psychiatrist as protagonist',
#       'sequel to:Silence Of The Lambs',
#       'subgenre:fairy tale',
#       'tale:Snow White (A-T #709)',
#       'puppetry',
#       'protagonist is a prostitute',
#       'rags to riches',
#       'horrifying (but not Horror genre)',
#       'police',
#       'protagonist sells cars',
#       'author:Charlotte Bronte',
#       'author:Dennis Cooper',
#       'might hate',
#       'author:Roald Dahl',
#       'sketch comedy',
#       'MST3K',
#       'animation & live action interact',
#       'author:Charles Dickens',
#       'animal:porpoise',
#       'claymation',
#       'author:Stella Gibbons',
#       'setting:farm',
#       'setting:London (UK)',
#       'setting:rural England',
#       'setting:Alcatraz',
#       'setting:prison',
#       'co-writer:Michael Crichton',
#       'related:007 (series)',
#       'Aardman studios',
#       'author:Peter George',
#       'compare:Fail-Safe',
#       'significant character in a wheelchair',
#       'US president',
#       'author:Irvine Walsh',
#       'related:Star Wars',
#       'author:Victor Hugo',
#       'sport:10 pin bowling',
#       'incest',
#       'character:Snake Plissken',
#       'cameo:Susie Bright',
#       'author:H. G. Wells',
#       'character:Michael Myers',
#       'subgenre:slasher',
#       'disambiguation:Mother Night/Night Mother',
#       'author:Ernest Hemingway',
#       "adapted from B'way",
#       'France',
#       'animal:cat',
#       'author:Truman Capote',
#       'death/fatality',
#       'gigolo',
#       'protagonist is a gold digger',
#       'eerie',
#       'nun (scene)',
#       'setting:San Francisco',
#       'amateur detective',
#       'remadeAs:Disturbia (2007)',
#       'remakeOf:Rear Window (1954)',
#       'Astaire and Rogers',
#       'Compare:Some Like It Hot',
#       'men disguised as women',
#       'protagonist is musician',
#       'quote:"five by five"',
#       'setting:Florida',
#       'setting:yacht',
#       'setting:nightclub/casino',
#       'author:Dashiell Hammett',
#       'source:Pygmalion myth',
#       'Bechdel test:pass (barely)',
#       'mostly about a single day',
#       'notable:taxi driver (scene)',
#       'protagonist is journalist/reporter',
#       'royal pretends to be commoner',
#       'setting:Rome',
#       'theme:elevation through self-sacrifice',
#       'colour/B&W combo',
#       'seeAlso:The Wizard of Oz (1939)',
#       'WizardOfOz',
#       'kept man/gigolo',
#       'loss of innocence',
#       'protagonist is actor',
#       'sardonic',
#       'setting:Hollywood',
#       'setting:movie studio',
#       'setting:Paramount studios',
#       'theme:ambition',
#       'theme:opportunism & exploitation',
#       'topic:Hollywood industry',
#       'author:Arthur C. Clarke',
#       'related:2001',
#       'setting:space/space ship',
#       '"bitchy"',
#       'great acting/subtle performances',
#       'great dialogue',
#       'protagonist is stage performer',
#       'sociopath',
#       'technique:narration over freeze-frame',
#       'author:Daphne Du Maurier',
#       'dwelling as character',
#       'Gothic',
#       'notable:F/X:fire',
#       'protagonist is servant',
#       'See also:Rebecca',
#       'overbearing mother',
#       'Related:Notorious (1946)',
#       'Oscar:Cinematography',
#       'scene:rendezvous in flower market',
#       'subgenre:cat burglar',
#       'setting:Paris',
#       'subgenre:farce',
#       'author:Vera Caspary',
#       'protagonist is journalist',
#       'author:John Steinbeck',
#       'Nick and Nora Charles (series)',
#       'remake of:The Front Page (1931)',
#       'subgenre:screwball',
#       'author:Jules Verne',
#       'angelic intervention',
#       'subgenre:political corruption',
#       'topic:US political corruption',
#       'AFI top 100 (#97)',
#       'AFI top 100 laughs (#14)',
#       'AFI top 100 passions (#51)',
#       'animal:leopard',
#       'Cary Grant&Katherine Hepburn',
#       'genre:romantic comedy',
#       'paleontologist as protagonist',
#       'plot point:dinosaur skeleton',
#       'psychiatrist as character',
#       'related:Bringing Up Baby (1938)',
#       'setting:golf course (scene)',
#       'subgenre:screwball farce',
#       'subgenre:slapstick (mild)',
#       'author:Somerset Maugham',
#       'bildungsroman',
#       'kuenstlerroman',
#       'not true to original version',
#       'Bogart & Hepburn',
#       '?author:Tennessee Williams',
#       'author:Hemingway',
#       'sport:ice hockey',
#       'Disney studios',
#       'telepathy',
#       'Herbie The Love Bug (series)',
#       'tear jerker',
#       'twins/inter-related lives?',
#       'sport:bobsledding',
#       'sport:baseball?',
#       'series:Pooh',
#       'Arthurian legend',
#       'author:P.L. Travers',
#       'comedy of manners',
#       'magical nanny',
#       'multiple roles',
#       'circus',
#       'mother-son relationship',
#       'orphaned cartoon character',
#       'subgenre:fable',
#       'animal:rabbit',
#       'author:Mary Norton',
#       'Bechdel Test:Pass (barely)',
#       'evil churchman',
#       'library (scene)',
#       'setting:WWII',
#       'sport:soccer football',
#       'author:Lewis Carroll',
#       'muscial band',
#       'Red Curtain trilogy',
#       'remadeAs:Charlie and the Chocolate...(2005)',
#       'remakeOf:Willy Wonka...(1971)',
#       'infidelity',
#       'stuttering',
#       '?alter ego',
#       'police detective',
#       'See:Dirty Dancing (1987)',
#       'brutal',
#       'playwright:David Mamet',
#       'writer:David Mamet',
#       'anti-government paranoia',
#       'children vs. parents',
#       'might dislike',
#       'sport:car racing (NASCAR)',
#       'fighter jet planes',
#       'military recruits/training',
#       'playwright:Tennessee Williams',
#       'setting:New Orleans',
#       'Inspector Clouseau (series)',
#       'Underwater',
#       'sport:boxing',
#       'centred on movie theatre',
#       "Jamie's Dad's favourites",
#       'setting:movie cinema',
#       'food/cooking?',
#       'deformity/disability',
#       'competition:dance',
#       'see also:Little Miss Sunshine',
#       'see also:Strictly Ballroom',
#       'sport:dancing',
#       'rock concert footage',
#       'author:Ken Kesey',
#       'lobotomy',
#       'setting:asylum',
#       'author:William Goldman',
#       'pirates (minor)',
#       'screenwriter:William Goldman',
#       'Kafka-esque',
#       'cult of masculinity',
#       'extraordinary!!!',
#       'no women',
#       'rape (implied)',
#       'author:Anthony Burgess',
#       'brainwashing',
#       'psychiatry',
#       'author:Harper Lee',
#       'insanity during war',
#       'no title sequence',
#       'cemetary funeral',
#       'disorientating',
#       'disorientation by foreign language',
#       'disorientation by soundtrack music',
#       'great visuals',
#       'novelist as protagonist',
#       'plot point:animal:cat',
#       'setting:Vienna',
#       'the nature of love',
#       'subgenre:haunted house',
#       'scuba diving',
#       'Shakespearean',
#       'remakeOf:Psycho (1960)',
#       'see also:Psycho (1960)',
#       'see also:Psycho (1998)',
#       'cameo-fest',
#       'gag:tossing lighter out of car',
#       'music:rhythm & blues',
#       'neo-Nazis',
#       'SNL alums',
#       'subgenre:buddies',
#       'author:Tom Wolfe',
#       'topic:NASA',
#       'submarine',
#       'deception to win wager',
#       'plot:wager',
#       'scam',
#       'death personified',
#       'playwright:Tom Stoppard',
#       'related:Hamlet',
#       'screenwriter:Tom Stoppard',
#       'melodrama',
#       'See also:Rumour Has It',
#       'Simon & Garfunkel soundtrack',
#       'RemakeOf:La Femme Nikita(1990)',
#       'cult of masulinity',
#       'Dark humour (not a comedy)',
#       'Nature of leadership',
#       'setting:POW camp',
#       'theme:civilization vs. anarchy',
#       'Yanks vs. Brits',
#       'remake of 8-and-a-half',
#       'cameo:Roman Polanski',
#       'prequel to:The Two Jakes',
#       'sequel to:Chinatown',
#       'water',
#       'Marx Brothers',
#       'alcholism',
#       'author:Stephen King',
#       'related:The Great Escape',
#       'utopia',
#       'weather reporter as protagonist',
#       'genre:western noir',
#       'assassin shooting in auditorium',
#       'incest (scene)',
#       'remakeOf:The Manchurian Candidate(1962)',
#       'US VP',
#       'clownish Cary Grant',
#       'frantic',
#       'newlyweds',
#       'mentor/trainer',
#       'related:Cyrano',
#       'current',
#       'notable:foot massage',
#       'related:High Noon',
#       'author:Raymond Chandler',
#       'Bogart & Bacall',
#       'character:Philip Marlowe',
#       'major reshooting',
#       'subgenre:sword and sandal',
#       'music:metal',
#       'plot point:television',
#       'Anglo-Indian relations',
#       'topic:Ghandi',
#       'author:Milan Kundera',
#       'author:E. M. Forster',
#       'plot point:sudden scientific insight',
#       'US college students',
#       'Rock Opera',
#       'sport:baseball',
#       'seeAlso:When Harry met Sally (1989)',
#       'Xmas theme?',
#       'animal:bird',
#       'animal:raven',
#       'character:Freddy Krueger',
#       'cameo:Whoopi Goldberg',
#       'even-numbered ST movie',
#       'author:Arthur Miller',
#       'remadeAs:101 Dalmations (1996)',
#       'remakeOf:101 Dalmations (1961)',
#       'character:Khan',
#       'villain:Penguin',
#       'sexist',
#       'animal:shark',
#       'author:Fennimore Cooper',
#       'character:Hawkeye',
#       'playwright:Andrew Lloyd Weber',
#       'author:J.G. Ballard',
#       'Cannes:special jury prize',
#       'disambiguation:Crash (1996/2004)',
#       'author:Leo Tolstoy',
#       'sexuality:necrophilia',
#       'Compare:Austin Powers',
#       'Compare:The Silencers',
#       'genre spoof',
#       'strong romantic subplot',
#       'competition',
#       'typography is important to cinematography',
#       'central event:wedding preparation(?)',
#       'switching places',
#       'author:Tom Clancy?',
#       'plot:small British community comes together',
#       'working class',
#       'Bechdel Test:Who Cares',
#       'descent into madness',
#       'deal with the devil',
#       'author:Dick King-Smith',
#       'author:Henry James',
#       'misfits trained into elite force',
#       'plot:making adult/pornographic films',
#       'reality TV',
#       'see also:The Truman Show',
#       'Oscar:screenplay',
#       'Chandleresque',
#       'related:The Big Sleep',
#       'SNL alum',
#       'adapted from:book series',
#       'author:Alexandre Dumas (pÃ¨re)',
#       'adapted from:play/opera',
#       'author:Hunter S. Thompson',
#       'author:Hugh Lofting',
#       'subgenre:cop buddies',
#       'Oscar:Best Picture',
#       'Oscar:Directing',
#       'poverty',
#       'competitive sport',
#       'subgenre:family dynamics',
#       'athletic apex',
#       'music by Vangelis',
#       'sport:track running',
#       'disambiguation:Repo Man/Repo Men',
#       'maze',
#       'muppets',
#       'character:Jason Vorhees',
#       'The Exorcist',
#       'Reaganomics',
#       'robot',
#       'natural disaster',
#       'remadeAs:Freaky Friday(2003)',
#       'remakeOf:Freaky Friday (1977)',
#       '"underaged sex"=child porn',
#       'author:Frank Herbert',
#       'massacred the book',
#       'author:E. Zola',
#       'Sherlock Holmes',
#       'documentary critique',
#       'author:Boris Pasternak',
#       '?social commentary',
#       'topic:AIDS/HIV',
#       'author:J.M. Barrie',
#       'SeeAlso:Hook (1991)',
#       'author:Ray Bradbury',
#       'author:S.E. Hinton',
#       'setting:in computer',
#       'Shakespearean references',
#       'pastiche',
#       'plot point:solving riddles/puzzles',
#       'author:J. R. R. Tolkein',
#       'author:George Orwell [Eric Blair]',
#       'assasination plot',
#       'bloodthirsty US president',
#       'not about ice hockey',
#       'disambiguation:...Ever After...',
#       'adaptedInto:Television series',
#       'animal:parrot',
#       'animal:seal',
#       'animal:spider',
#       'author:E. B. White',
#       'technique:puppetry',
#       'Amblin',
#       'disambiguation:The Avengers (1998)/(2012)',
#       'miniature sets',
#       'referred to in RHPS',
#       'Academy award:Best Song',
#       'civilian caught up in intrigue',
#       'remade by same director',
#       'score: Bernard Hermann',
#       'setting:Marrakech',
#       'setting:North Africa',
#       'setting:Royal Albert Hall',
#       'actors',
#       'SERIAL KILLERS',
#       'setting',
#       'subplot:ingenue is aide to antiheroine',
#       'comedy about witness protection/relocation',
#       'witness protection programme',
#       'disambiguation:Toy(s)',
#       'weapons industry',
#       'female stripper (scene)',
#       'photographer as protagonist',
#       'protagonist is photographer',
#       'Mick Travis (series)',
#       'cameo:Bruce Willis',
#       'Depp & Burton',
#       'nazis',
#       'BREAKUPS AND DIVORCES',
#       'dysfunctional family',
#       'genre:historical fiction',
#       'SequelTo:Elizabeth',
#       'Slasher',
#       'plot point:lottery ticket',
#       'town vs. country',
#       'subgenre:Kaiju',
#       'technique:Stop-motion special effects',
#       'woman carried onto tall building',
#       'setting:jungle',
#       'Hitchcock',
#       'mother-daughter relationships',
#       'mercenary as protagonist',
#       'setting:Colombia',
#       'DVD:alternate endings',
#       'genre:movie as whodunit',
#       'National Lampoon',
#       'topic:Oscar Wilde',
#       'sequelTo:The Fly (1958)',
#       'author:Umberto Eco',
#       'setting:monastery',
#       'competition:pool billiards',
#       'plot point:time is short',
#       'remadeAs:Payback(1999)',
#       'remakeOf:Point Blank(1967)',
#       'author:Kurt Vonnegut Jr.',
#       'dwelling a character',
#       'aging',
#       'scifi re aging',
#       '"damn dirty apes"',
#       'psychiatrist',
#       'author:Shirley Jackson',
#       'physician as protagonist',
# ...
#       'not funny',
#       'Funny',
#       'very funny',
#       'not funny at all',
#       'funny!',
#       'Not as funny',
#       'Not funny',
#       'funny once',
#       'very funny!',
#       'not too much funny',
#       'so funny!',
#       'not very funny',
#       'not funny enough',
#       'Very funny',
#       'So funny',
#       'Very funny!',
#       'SO funny',
#       'This is funny',
#       'Too funny!!',
#       'sometimes funny',
#       'not that funny',
#       'how was this funny?'],
#  13: ['weird', 'too weird', 'Weird', 'weird!', 'weird.'],
#  14: ['coming of age',
#       'coming-of-age',
#       'Coming of age',
#       'Coming Of Age',
#       'Coming of Age',
#       'Coming-of-Age',
#       'Coming-Of-Age'],
#  15: ['ending',
#       'Ending',
#       'no ending',
#       'over-the-top ending',
#       'what an ending',
#       'the ending',
#       'that ending...',
#       'over the top ending',
#       'not much of an ending',
#       'The ending',
#       'ending.'],
#  16: ['Hollywood',
#       'Too Hollywood',
#       'hollywood',
#       'NOT HOLLYWOOD!',
#       'very Hollywood'],
#  17: ['action',
#       'Action',
#       'no action',
#       'over-the-top action',
#       'ACTION',
#       'not action',
#       'Over-the-top action.',
#       'too much action',
#       'to see: action',
#       'Not enough action',
#       'The action',
#       'all action',
#       'not enough action'],
#  18: ['too much love interest',
#       'love',
#       'FIRST LOVE',
#       'First love',
#       'first love',
#       'love is not enough',
#       'you will love it.',
#       'Love'],
#  19: ['plot',
#       'no plot',
#       'the plot',
#       'No plot!!!',
#       'thin plot',
#       'Plot',
#       'The plot',
#       'full plot',
#       'plot.'],
#  20: ['boring',
#       'BORING!',
#       'Boring',
#       'very boring',
#       'boring!',
#       'so boring',
#       'Boring?',
#       'Boring after 2/3',
#       'but boring',
#       'sometimes boring'],
#  21: ['intense',
#       'Intense',
#       'too intense',
#       'not intense enough',
#       'Too intense',
#       'Very intense',
#       'very intense'],
#  22: ['black and white',
#       'black & white',
#       'black-and-white',
#       'Black & White',
#       'mostly black and white'],
#  23: ['classic',
#       'Classic',
#       'to see: classic',
#       'a classic',
#       'classic!!!',
#       'a classic!!',
#       'Classic!',
#       'but a classic'],
#  24: ['love story',
#       'no love story',
#       'Love story',
#       'Love Story',
#       'not a love story'],
#  25: ['need to own',
#       'need to see',
#       'no need to see',
#       'May need to see again',
#       'need to see again'],
#  26: ['based on a book',
#       'based on book',
#       'not based on a book',
#       'Based on a book',
#       'BASED ON BOOK',
#       'Based on a Book',
#       'Based On A Book',
#       'Based on Book',
#       'Based on book',
#       'Based on the book',
#       'based off book',
#       'based on  a book',
#       'Based and a book'],
#  27: ['chick flick',
#       'Chick Flick',
#       'Chick flick',
#       'to see: chick flick',
#       'a chick flick',
#       'chick-flick'],
#  28: ['violent', 'Violent', 'very violent', 'too violent', 'Very violent'],
#  29: ['mystery',
#       'Mystery',
#       'No mystery',
#       'few mystery',
#       'Not much of a mystery'],
#  30: ['unrealistic',
#       'very unrealistic',
#       'too unrealistic',
#       'unrealistic but well done',
#       'Unrealistic'],
#  31: ['realistic',
#       'Realistic',
#       'sometimes not realistic enough',
#       'not realistic',
#       'Not very realistic'],
#  32: ['cliche',
#       'Cliche',
#       'not cliche',
#       'cliché',
#       'cliche after cliche',
#       'Cliché'],
#  33: ['too long',
#       'long',
#       'Too Long!',
#       'Too long',
#       'Too Long',
#       'almost too long',
#       'Long',
#       'TOO LONG',
#       'Very long',
#       'over long',
#       'very long',
#       'SO LONG',
#       'long take',
#       'but long'],
#  34: ['martial arts',
#       'Martial Arts',
#       'martial-arts',
#       'few martial arts',
#       'Martial arts'],
#  35: ['dark', 'too dark', 'Dark', 'dark side', 'DARK', 'not dark enough'],
#  36: ['violence',
#       'over the top violence',
#       'too much violence',
#       'Violence',
#       'R:violence',
#       'r:violence',
#       'violence.',
#       'R:some violence',
#       'r:some violence',
#       'TOO much violence'],
#  37: ['blood',
#       'no blood',
#       'too much blood',
#       'Some blood',
#       'blood.',
#       'Blood',
#       'not enough blood'],
#  38: ['Samuel L. Jackson',
#       'Samuel L.Jackson',
#       'samuel jackson',
#       'Samuel L Jackson',
#       'samuel l. jackson'],
#  39: ['slow', 'Slow', 'too slow', 'but too slow', 'very slow', 'Too slow'],
#  40: ['gay', 'Gay', 'Gay Interest', 'gay interest', 'so gay!'],
#  41: ['acting', 'the acting', 'Acting', 'over the top acting', 'The acting'],
#  42: ['language',
#       'R language',
#       'R:language',
#       'R:some language',
#       'Language',
#       'made-up language',
#       'R (Language)'],
#  43: ['based on a true story',
#       'Based on a true story',
#       'based on a true story?',
#       'based on true story',
#       'Based On A True Story',
#       'based upon a true story'],
#  44: ['touching',
#       'Touching',
#       'A very touching',
#       'Very touching',
#       'the most touching'],
#  45: ['very moving',
#       'moving',
#       'Moving',
#       'Not moving',
#       'not very moving though'],
#  46: ['"found footage"',
#       'found footage',
#       'Found footage',
#       'NOT found footage',
#       'Found Footage'],
#  47: ['creepy',
#       'Creepy',
#       'too creepy',
#       'it was creepy',
#       'CREEPY',
#       'very creepy'],
#  48: ['cgi', 'CGI', 'no CGI', 'CGI B/W', 'Too Much CGI', 'too much cgi'],
#  49: ['predictable',
#       'Predictable',
#       'too predictable',
#       'Too predictable',
#       'very predictable'],
#  50: ['children',
#       'Children',
#       'For children',
#       'not children',
#       'not for children',
#       'for children',
#       "children's",
#       'alone children',
#       'children.'],
#  51: ['Matt Damon',
#       'matt damon',
#       'matt damon!',
#       'matt damon;',
#       '*NOT* Matt Damon'],
#  52: ['story',
#       'thin story',
#       'story within a story',
#       'Story',
#       'not much of a story',
#       'story-in-a-story',
#       'side story',
#       'no story',
#       'same story',
#       'back story',
#       'back-story',
#       'The story',
#       'the story'],
#  53: ['horror',
#       'Horror',
#       'not horror',
#       'to see: horror',
#       'not a horror',
#       'NOT HORROR!',
#       'NOT horror'],
#  54: ['bad',
#       'not bad.',
#       'SO bad',
#       'very bad',
#       'Bad',
#       'bad even for me',
#       'not bad',
#       'bad one',
#       'not that bad',
#       'bad everything',
#       'Not bad',
#       "so bad it's bad",
#       'bad bad',
#       'bad!',
#       'but bad'],
#  55: ['sad',
#       'So sad',
#       'very sad',
#       'SAD',
#       'Sad',
#       'too sad',
#       'so sad',
#       'and sad'],
#  56: ['history', 'History', 'US history', 'my history', 'US History'],
#  57: ['dialogue',
#       'too much dialogue',
#       'no dialogue',
#       'Dialogue<3',
#       'Dialogue',
#       'The dialogue',
#       'thin dialogue'],
#  58: ['film noir',
#       'first ever film noir',
#       'Film Noir',
#       'Film-Noir',
#       'film-noir'],
#  59: ['end of the world',
#       'END OF THE WORLD',
#       'End of the world',
#       'the end of the world',
#       'end of world'],
#  60: ['sequel', 'so so sequel', 'Sequel', 'no sequel', 'why a sequel?'],
#  61: ['stand-up comedy',
#       'stand up comedy?',
#       'Stand up Comedy',
#       'stand up comedy',
#       'Stand-up comedy',
#       'Stand-Up Comedy'],
#  62: ['Great Movie!',
#       'Great movie',
#       'GREAT MOVIE',
#       'Great b&w movie',
#       'great movie',
#       'Great Movie',
#       'GREAT movie',
#       'Not a great movie'],
#  63: ['original',
#       'nothing original',
#       'not original',
#       'Original',
#       'very original'],
#  64: ['Gross', 'Gross-out', 'gross out', 'gross', 'gross-out'],
#  65: ['Good',
#       'not very good.',
#       'good',
#       'good cry',
#       'very good',
#       'Good A.I.',
#       'Good for what it is',
#       'not good',
#       'not that good',
#       'not good at all',
#       'so good',
#       'not as good as ...',
#       'very good!',
#       'Good but not that good',
#       'not so good',
#       'Very good!',
#       'not very good',
#       'but good',
#       'but not very good',
#       'VERY good'],
#  66: ['World War I',
#       'World War 2',
#       'world war I',
#       'world war 2',
#       'World war 2'],
#  67: ['con men', 'X-men', 'x-men', 'men', 'x men', 'X-Men V'],
#  68: ['serial killer',
#       'Serial killer',
#       'serial killer;',
#       'Serial Killer',
#       'Serial KIller'],
#  69: ['not true to the book',
#       'not true to book',
#       'True to book',
#       'True to the book',
#       'true to book',
#       'True to Book',
#       'Not True to Book',
#       'Not True to the Book'],
#  70: ['for kids',
#       'kids',
#       'Kids',
#       'For kids',
#       'no kids',
#       'not for kids',
#       'but mostly for kids',
#       '(mostly) for kids',
#       'not only for kids',
#       'for the kids',
#       'kids only',
#       'to kids'],
#  71: ['Watch',
#       'watch it more than once',
#       'watch again',
#       're-watch',
#       'To Watch',
#       'to watch',
#       'Watch the First Two First',
#       'must watch',
#       'Watch Again',
#       'One watch only',
#       'someone to watch over me',
#       'watch',
#       'I can watch it again',
#       'never watch again',
#       'Watch This',
#       'watch-again',
#       'Watch again',
#       'Must Watch/Own!'],
#  72: ['scary',
#       'almost scary',
#       'Scary',
#       'not scary',
#       'not scary enough',
#       'too scary',
#       'very scary',
#       'not too scary'],
#  73: ['want to see again',
#       'want to see',
#       'Want',
#       'want to own',
#       'want it',
#       'never want to see',
#       'want to see again!'],
#  74: ['southern US', 'southern', 'Southern US', 'Southern', 'southern us'],
#  75: ['God', 'god', 'why god why', 'why god', 'No Please god no!'],
#  76: ['game', 'game show', 'No Game', 'game over', 'go game'],
#  77: ['Bechdel Test:Pass',
#       'Bechdel test:Pass',
#       'Bechdel Test: pass',
#       'Bechdel Test: Pass',
#       'Bechdel Test - pass',
#       'bechdel test:pass',
#       'bechdel test: pass',
#       'Bechdel test: pass'],
#  78: ['Based on a TV show',
#       'based on a TV show',
#       'Based on a TV show?',
#       'based on a tv show',
#       'Based on a TV Show'],
#  79: ['might not like',
#       'should not like',
#       'will not like',
#       'like',
#       'might like',
#       'i like you',
#       'not enough like it',
#       'should like',
#       'will like'],
#  80: ['Made for TV',
#       'made for TV',
#       'TV',
#       'tv show',
#       'TV show',
#       'tv',
#       'made for tv',
#       'TV-G'],
#  81: ['The Beatles', 'Beatles', 'The Beatles (NOT!)', 'beatles', 'the beatles'],
#  82: ['nudity',
#       'no nudity',
#       'Nudity',
#       'R:nudity',
#       'not enough nudity',
#       'R:some nudity'],
#  83: ['Based on a TV series',
#       'based on tv series',
#       'based on TV series',
#       'based on a TV series',
#       'based on a tv series'],
#  84: ['fun', 'Fun', 'fun enough', 'for fun', "but it's fun."],
#  85: ['only a few jokes', 'jokes', 'in jokes', 'Jokes', 'few jokes'],
#  86: ['full of cliches',
#       'Cliches',
#       'cliches',
#       'some cliches',
#       'Too many cliches'],
#  87: ['character development',
#       'no character development.',
#       'Character development',
#       'no character development',
#       'Character Development',
#       'not much character development'],
#  88: ['romantic',
#       'The most romantic',
#       'not romantic',
#       'ROMANTIC',
#       'Romantic',
#       'so romantic.'],
#  89: ['the show is better',
#       'could have been better',
#       'Better than the First',
#       'better than the first',
#       'better than first part',
#       'first was much better',
#       'nothing better than this',
#       'Much better than the first',
#       'should have been better',
#       'but better!',
#       'better than the show',
#       'better',
#       'Could have been better'],
#  90: ['my favourite',
#       'favourite',
#       'My favourite of all',
#       'My Favourite',
#       'almost favourite'],
#  91: ['Cool.',
#       'cool',
#       'not cool',
#       'that was cool.',
#       'COOL',
#       'so cool',
#       'Cool',
#       'Very cool.'],
#  92: ['Very interesting.',
#       'Very interesting',
#       'interesting',
#       'Interesting',
#       'not interesting',
#       'very interesting'],
#  93: ['rated-R',
#       'over-rated',
#       'b-rated',
#       'rated-G',
#       'Over-rated',
#       'R-rated',
#       'Rated R',
#       'under-rated',
#       'Why is this rated R?'],
#  94: ["So bad it's good",
#       "so bad it's good",
#       'So bad its good',
#       "so bad it's almost good",
#       'so bad its good',
#       'bad but good',
#       'so-bad-its-good',
#       'bad to good',
#       'so bad it is good',
#       'Not Bad Not Good'],
#  95: ['SEE IN IMAX', 'IMAX', 'imax', 'Imax', 'IMAX 3-D'],
#  96: ['dvd',
#       'dvd-r',
#       "can't find on DVD",
#       'DVD',
#       'Not on dvd',
#       'Not on DVD',
#       'not on DVD',
#       'DVD-R'],
#  97: ['Best one',
#       'the best you could do',
#       'The Best!',
#       'one of the best',
#       'the best of',
#       'not his best',
#       'best ever',
#       'Best ever',
#       'best one yet',
#       'the best one'],
#  98: ['excellent',
#       'excellent!',
#       'Excellent',
#       'but still excellent',
#       'excellent - must see'],
#  99: ['Based on a comic book',
#       'based on comic book',
#       'based on a comic book',
#       'Based On Comic Book',
#       'based-comic-book'],
#  100: ['2 movies in 1',
#        'movies',
#        'Movies 8',
#        'movies 6',
#        'movies 8',
#        'My movies',
#        'movies about movies'],
#  101: ['best movie ever made',
#        'best movie ever',
#        'the best movie ever!!!!!!!!',
#        'best-movie',
#        'Best Movie Ever',
#        'the best movie ever made',
#        'best movie'],
#  102: ['lame', 'lame!', 'Lame everything', 'lame name', 'Lame'],
#  103: ['he-man',
#        'one man show',
#        'con man',
#        'man with no name',
#        'one man show.'],
#  104: ['wtf?', 'wtf?!', 'WTF', 'wtf', 'WTF?'],
#  105: ['Amazing',
#        'amazing',
#        'Amazing!',
#        'amazing!',
#        'amazing c',
#        'amazing!.',
#        'so amazing',
#        'AMAZING!'],
#  106: ['terrible',
#        'Terrible',
#        'Terrible Terrible',
#        'the first one was terrible',
#        'Everything is Terrible',
#        'not terrible'],
#  107: ['nice',
#        'Nice',
#        'nice enough to see again',
#        'very nice',
#        'it was only nice',
#        'too nice'],
#  108: ['great',
#        'could have been great',
#        'still great',
#        'Great',
#        'not great',
#        'not  great'],
#  109: ['AFI #2',
#        'AFI #9',
#        'AFI #3',
#        'AFI #6',
#        'AFI #4',
#        'AFI #1',
#        'AFI #5',
#        'AFI #7',
#        'AFI #8',
#        'afi'],
#  110: ['legend', 'I am Legend', 'I Am Legend', 'A Legend', 'Legend'],
#  111: ['how to rate?',
#        "can't rate",
#        'rate up',
#        'rate down',
#        'rate-down',
#        'rate'],
#  112: ['night', 'Night', 'one night', 'M.Night', 'keep you up at night'],
#  113: ['7.5-FilmAffinity',
#        '7.2-FilmAffinity',
#        '6,5-filmaffinity',
#        '8.7-FilmAffinity',
#        '7.4-FilmAffinity',
#        '8.4-FilmAffinity',
#        '8.2-FilmAffinity',
#        '8.3-FilmAffinity',
#        '7.6-FilmAffinity',
#        '6.5-FilmAffinity',
#        '7.0-FilmAffinity',
#        '6.8-FilmAffinity',
#        '7.1-FilmAffinity',
#        '7.8-FilmAffinity',
#        '7.3-FilmAffinity',
#        '6,2-filmaffinity',
#        '5.7-FilmAffinity',
#        '7.7-FilmAffinity',
#        '6.3-FilmAffinity',
#        '6.7-FilmAffinity',
#        '5,4-filmaffinity',
#        '6.4-FilmAffinity',
#        '6.2-FilmAffinity',
#        '6.1-FilmAffinity',
#        '5.5-FilmAffinity',
#        '5.8-FilmAffinity',
#        '5.9-FilmAffinity',
#        '5.3-FilmAffinity',
#        '5.1-FilmAffinity',
#        '5-FilmAffinity'],
#  114: ['1-4-2007',
#        '7-2007',
#        '7-4-2007',
#        '6-4-2007',
#        '5-8-2007',
#        '9-2007',
#        '9-2-2007']}
